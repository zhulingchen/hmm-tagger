# %% [markdown]
# # Project: Part of Speech Tagging with Hidden Markov Models
# ---
# ### Introduction
#
# Part of speech tagging is the process of determining the syntactic category of a word from the words in its surrounding context. It is often used to help disambiguate natural language phrases because it can be done quickly with high accuracy. Tagging can be used for many NLP tasks like determining correct pronunciation during speech synthesis (for example, _dis_-count as a noun vs dis-_count_ as a verb), for information retrieval, and for word sense disambiguation.
#
# In this notebook, you'll use the [Pomegranate](http://pomegranate.readthedocs.io/) library to build a hidden Markov model for part of speech tagging using a "universal" tagset. Hidden Markov models have been able to achieve [>96% tag accuracy with larger tagsets on realistic text corpora](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf). Hidden Markov models have also been used for speech recognition and speech generation, machine translation, gene recognition for bioinformatics, and human gesture recognition for computer vision, and more.
#
# ![](_post-hmm.png)
#
# The notebook already contains some code to get you started. You only need to add some new functionality in the areas indicated to complete the project; you will not need to modify the included code beyond what is requested. Sections that begin with **'IMPLEMENTATION'** in the header indicate that you must provide code in the block that follows. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You must then **export the notebook** by running the last cell in the notebook, or by using the menu above and navigating to **File -> Download as -> HTML (.html)** Your submissions should include both the `html` and `ipynb` files.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Code and Markdown cells can be executed using the `Shift + Enter` keyboard shortcut. Markdown cells can be edited by double-clicking the cell to enter edit mode.
# </div>

# %% [markdown]
# ### The Road Ahead
# You must complete Steps 1-3 below to pass the project. The section on Step 4 includes references & resources you can use to further explore HMM taggers.
#
# - [Step 1](#Step-1:-Read-and-preprocess-the-dataset): Review the provided interface to load and access the text corpus
# - [Step 2](#Step-2:-Build-a-Most-Frequent-Class-tagger): Build a Most Frequent Class tagger to use as a baseline
# - [Step 3](#Step-3:-Build-an-HMM-tagger): Build an HMM Part of Speech tagger and compare to the MFC baseline
# - [Step 4](#Step-4:-[Optional]-Improving-model-performance): (Optional) Improve the HMM tagger

# %% [markdown]
# <div class="alert alert-block alert-warning">
# **Note:** Make sure you have selected a **Python 3** kernel in Workspaces or the hmm-tagger conda environment if you are running the Jupyter server on your own machine.
# </div>

# %%
# Jupyter "magic methods" -- only need to be run once per kernel restart
# %load_ext autoreload
# %aimport helpers, tests
# %autoreload 1

# %%
# import python modules -- this cell needs to be run again if you make changes to any of the files
import matplotlib.pyplot as plt
import numpy as np

from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict
from helpers import show_model, Dataset
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution

# %% [markdown]
# ## Step 1: Read and preprocess the dataset
# ---
# We'll start by reading in a text corpus and splitting it into a training and testing dataset. The data set is a copy of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus) (originally from the [NLTK](https://www.nltk.org/) library) that has already been pre-processed to only include the [universal tagset](https://arxiv.org/pdf/1104.2086.pdf). You should expect to get slightly higher accuracy using this simplified tagset than the same model would achieve on a larger tagset like the full [Penn treebank tagset](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html), but the process you'll follow would be the same.
#
# The `Dataset` class provided in helpers.py will read and parse the corpus. You can generate your own datasets compatible with the reader by writing them to the following format. The dataset is stored in plaintext as a collection of words and corresponding tags. Each sentence starts with a unique identifier on the first line, followed by one tab-separated word/tag pair on each following line. Sentences are separated by a single blank line.
#
# Example from the Brown corpus.
# ```
# b100-38532
# Perhaps	ADV
# it	PRON
# was	VERB
# right	ADJ
# ;	.
# ;	.
#
# b100-35577
# ...
# ```

# %%
data = Dataset("tags-universal.txt", "brown-universal.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 57340 sentences in the corpus.
# There are 45872 sentences in the training set.
# There are 11468 sentences in the testing set.

# %% [markdown]
# ### The Dataset Interface
#
# You can access (mostly) immutable references to the dataset through a simple interface provided through the `Dataset` class, which represents an iterable collection of sentences along with easy access to partitions of the data for training & testing. Review the reference below, then run and review the next few cells to make sure you understand the interface before moving on to the next step.
#
# ```
# Dataset-only Attributes:
#     training_set - reference to a Subset object containing the samples for training
#     testing_set - reference to a Subset object containing the samples for testing
#
# Dataset & Subset Attributes:
#     sentences - a dictionary with an entry {sentence_key: Sentence()} for each sentence in the corpus
#     keys - an immutable ordered (not sorted) collection of the sentence_keys for the corpus
#     vocab - an immutable collection of the unique words in the corpus
#     tagset - an immutable collection of the unique tags in the corpus
#     X - returns an array of words grouped by sentences ((w11, w12, w13, ...), (w21, w22, w23, ...), ...)
#     Y - returns an array of tags grouped by sentences ((t11, t12, t13, ...), (t21, t22, t23, ...), ...)
#     N - returns the number of distinct samples (individual words or tags) in the dataset
#
# Methods:
#     stream() - returns an flat iterable over all (word, tag) pairs across all sentences in the corpus
#     __iter__() - returns an iterable over the data as (sentence_key, Sentence()) pairs
#     __len__() - returns the nubmer of sentences in the dataset
# ```
#
# For example, consider a Subset, `subset`, of the sentences `{"s0": Sentence(("See", "Spot", "run"), ("VERB", "NOUN", "VERB")), "s1": Sentence(("Spot", "ran"), ("NOUN", "VERB"))}`. The subset will have these attributes:
#
# ```
# subset.keys == {"s1", "s0"}  # unordered
# subset.vocab == {"See", "run", "ran", "Spot"}  # unordered
# subset.tagset == {"VERB", "NOUN"}  # unordered
# subset.X == (("Spot", "ran"), ("See", "Spot", "run"))  # order matches .keys
# subset.Y == (("NOUN", "VERB"), ("VERB", "NOUN", "VERB"))  # order matches .keys
# subset.N == 7  # there are a total of seven observations over all sentences
# len(subset) == 2  # because there are two sentences
# ```
#
# <div class="alert alert-block alert-info">
# **Note:** The `Dataset` class is _convenient_, but it is **not** efficient. It is not suitable for huge datasets because it stores multiple redundant copies of the same data.
# </div>

# %% [markdown]
# #### Sentences
#
# `Dataset.sentences` is a dictionary of all sentences in the training corpus, each keyed to a unique sentence identifier. Each `Sentence` is itself an object with two attributes: a tuple of the words in the sentence named `words` and a tuple of the tag corresponding to each word named `tags`.

# %%
key = 'b100-38532'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: b100-38532
# words:
# 	('Perhaps', 'it', 'was', 'right', ';', ';')
# tags:
# 	('ADV', 'PRON', 'VERB', 'ADJ', '.', '.')

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** The underlying iterable sequence is **unordered** over the sentences in the corpus; it is not guaranteed to return the sentences in a consistent order between calls. Use `Dataset.stream()`, `Dataset.keys`, `Dataset.X`, or `Dataset.Y` attributes if you need ordered access to the data.
# </div>
#
# #### Counting Unique Elements
#
# You can access the list of unique words (the dataset vocabulary) via `Dataset.vocab` and the unique list of tags via `Dataset.tagset`.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 1161192 samples of 56057 unique words in the corpus.
# There are 928458 samples of 50536 unique words in the training set.
# There are 232734 samples of 25112 unique words in the testing set.
# There are 5521 words in the test set that are missing in the training set.

# %% [markdown]
# #### Accessing word and tag Sequences
# The `Dataset.X` and `Dataset.Y` attributes provide access to ordered collections of matching word and tag sequences for each sentence in the dataset.

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.')
#
# Labels 1: ('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
# Sentence 2: ('But', 'there', 'seemed', 'to', 'be', 'some', 'difference', 'of', 'opinion', 'as', 'to', 'how', 'far', 'the', 'board', 'should', 'go', ',', 'and', 'whose', 'advice', 'it', 'should', 'follow', '.')
#
# Labels 2: ('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.')

# %% [markdown]
# #### Accessing (word, tag) Samples
# The `Dataset.stream()` method returns an iterator that chains together every pair of (word, tag) entries across all sentences in the entire corpus.

# %%
# use Dataset.stream() (word, tag) samples for the entire corpus
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 5: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('Mr.', 'NOUN')
# 	 ('Podger', 'NOUN')
# 	 ('had', 'VERB')
# 	 ('thanked', 'VERB')
# 	 ('him', 'PRON')
# 	 ('gravely', 'ADV')
# 	 (',', '.')

# %% [markdown]
# For both our baseline tagger and the HMM model we'll build, we need to estimate the frequency of tags & words from the frequency counts of observations in the training corpus. In the next several cells you will complete functions to compute the counts of several sets of counts.

# %% [markdown]
# ## Step 2: Build a Most Frequent Class tagger
# ---
#
# Perhaps the simplest tagger (and a good baseline for tagger performance) is to simply choose the tag most frequently assigned to each word. This "most frequent class" tagger inspects each observed word in the sequence and assigns it the label that was most often assigned to that word in the corpus.

# %% [markdown]
# ### IMPLEMENTATION: Pair Counts
#
# Complete the function below that computes the joint frequency counts for two input sequences.

# %%
def pair_counts(sequences_A, sequences_B):
    """Return a dictionary keyed to each unique value in the first sequence list
    that counts the number of occurrences of the corresponding value from the
    second sequences list.
    
    For example, if sequences_A is tags and sequences_B is the corresponding
    words, then if 1244 sequences contain the word "time" tagged as a NOUN, then
    you should return a dictionary such that pair_counts[NOUN][time] == 1244
    """
    # TODO: Finish this function!
    assert len(sequences_A) == len(sequences_B), "Sequence A and B should have the same length"
    pc_dict = {}
    
    for tag, word in zip(sequences_A, sequences_B):
        if tag not in pc_dict:
            pc_dict[tag] = {}
        if word not in pc_dict[tag]:
            pc_dict[tag][word] = 0
        pc_dict[tag][word] += 1
        
    return pc_dict


# Calculate C(t_i, w_i)
tags = [tag for word, tag in data.stream()]
words = [word for word, tag in data.stream()]

emission_counts = pair_counts(tags, words)

# check pair count outputs
for tag, word_dict in emission_counts.items():
    print("{}: {}".format(tag, word_dict))

assert len(emission_counts) == 12, \
       "Uh oh. There should be 12 tags in your dictionary."
assert max(emission_counts["NOUN"], key=emission_counts["NOUN"].get) == 'time', \
       "Hmmm...'time' is expected to be the most common NOUN."
HTML('<div class="alert alert-block alert-success">Your emission counts look good!</div>')
# Out:
# NOUN: {'Mr.': 844, 'Podger': 21, 'use': 352, 'advice': 50, 'difference': 148, 'opinion': 94, 'board': 165, 'instrument': 44, 'elasticity': 5, 'pastes': 1, 'inks': 1, 'paints': 6, 'adhesives': 2, 'plastics': 28, 'bread': 41, 'dough': 13, 'properties': 61, 'length': 115, 'shortness': 1, 'spinnability': 1, 'methods': 138, 'present': 44, 'plans': 96, 'language': 106, 'teacher': 78, 'east': 41, 'mile': 42, 'road': 178, 'effort': 145, 'sweat': 19, 'television': 49, 'Line': 15, 'tour': 39, 'Beach': 28, 'night': 398, 'opportunity': 120, 'measure': 60, 'adversary': 5, 'war': 304, "Khrushchev's": 14, 'intentions': 22, 'views': 49, 'direction': 132, 'place': 475, 'philosopher': 16, 'Samuel': 34, "Alexander's": 3, 'debt': 13, 'Wordsworth': 2, 'Meredith': 18, 'example': 287, 'A.': 110, 'N.': 26, "Whitehead's": 2, 'understanding': 82, 'romantics': 5, 'Shelley': 12, 'network': 30, 'entities': 11, 'manner': 124, 'regard': 53, 'needs': 93, 'society': 192, 'regime': 23, "corporation's": 5, 'survival': 30, 'responsibility': 116, 'conditions': 179, 'assistance': 85, 'scale': 53, 'definition': 34, 'objectives': 39, 'assessment': 22, 'costs': 160, 'Theresa': 24, 'Anne': 42, 'George': 129, 'degree': 125, 'Af': 994, 'P': 47, 'teen': 2, 'life': 676, 'non-college': 1, 'group': 377, 'sense': 301, 'marginality': 2, 'tempest': 1, 'March': 97, 'Udall': 6, 'bronze': 8, 'statue': 16, 'William': 147, 'Jennings': 3, 'Bryan': 12, 'Gutzon': 1, 'Borglum': 2, 'loan': 41, 'Salem': 19, 'Illinois': 40, "Bryan's": 2, 'birthplace': 6, 'case': 353, 'elements': 103, 'pencil': 34, 'secant': 12, 'line': 279, 'vertex': 19, 'intersection': 17, '**zg': 32, 'plane': 111, 'howl': 3, 'coming': 12, 'times': 260, 'veterinarian': 2, 'Kennan': 7, 'account': 90, 'circumstance': 12, 'atmosphere': 79, 'decisions': 52, 'approach': 107, 'integration': 47, 'formation': 37, 'Market': 12, 'Euratom': 1, 'cooperation': 36, 'development': 309, 'energy': 96, 'one': 482, 'prestige': 27, 'management': 88, 'position': 235, 'minds': 56, 'people': 809, 'things': 361, 'holes': 38, 'art': 178, 'movies': 30, 'girl': 211, 'dreams': 24, 'flower': 17, 'elbows': 7, 'body': 269, 'potato': 15, 'tune-belly': 1, 'jury': 63, 'Fulton': 17, "ordinary's": 1, 'court': 118, 'fire': 160, 'practices': 49, 'appointment': 26, 'appraisers': 1, 'guardians': 4, 'administrators': 5, 'awarding': 1, 'fees': 27, 'compensation': 17, 'precedent': 9, 'time': 1555, 'capture': 4, 'Helion': 18, 'person': 170, 'sketchbook': 2, "Woolworth's": 1, 'York': 302, 'boat': 69, 'frames': 26, 'contact': 53, 'plywood': 9, 'planking': 8, 'significance': 66, 'volume': 115, 'paragraphs': 14, 'Laguerre': 3, 'Hanover': 66, 'Tar': 10, 'Heel-Lotus': 2, 'radioactivity': 3, 'fallout': 31, 'Cavalry': 10, 'troopers': 5, 'Palace': 23, 'Emperor': 12, 'tonight': 34, 'Earl': 11, 'examples': 47, 'abuse': 13, 'passages': 20, 'Examiner': 8, 'Destroyer': 1, 'Character': 1, 'Richard': 71, 'Steele': 21, 'Swift': 20, 'truth': 124, 'men': 736, 'treatment': 122, 'Robert': 83, 'E.': 85, 'Lee': 34, 'dignity': 34, 'confederacy': 3, 'Heat': 6, 'transfer': 32, 'conduction': 2, 'radiation': 91, 'arc': 40, 'column': 60, 'maps': 13, 'program': 367, 'step': 110, 'division': 66, 'long-range': 40, 'state': 524, 'plan': 166, 'series': 122, 'inch': 39, 'sheets': 26, 'feet': 283, 'Hong': 11, 'Kong': 11, 'India': 58, 'Pakistan': 7, 'exports': 10, 'types': 114, 'textiles': 15, 'Britain': 55, 'years': 942, 'Lancashire': 1, 'Pact': 3, 'day': 623, 'dogs': 66, 'Ireland': 13, 'pigs': 6, 'fans': 19, 'room': 365, 'remnants': 2, 'smoke': 32, 'strata': 2, 'ceiling': 31, 'ship': 76, 'Discovery': 12, 'crew': 36, 'nuclei': 13, 'fibers': 23, 'Figures': 13, 'proliferation': 5, 'structure': 90, 'center': 175, 'periphery': 5, 'fiber': 27, 'presence': 75, 'artery': 46, 'anastomoses': 6, 'Ruysch': 1, 'others': 294, 'information': 258, 'sampling': 10, 'assesment': 1, 'techniques': 98, 'advisers': 12, 'attention': 177, 'uninitiate': 1, 'confusion': 43, 'operator': 49, 'anybody': 39, 'campaign': 75, 'Mit ...
# VERB: {'had': 5101, 'thanked': 6, 'made': 1119, 'seemed': 333, 'be': 6342, 'should': 865, 'go': 604, 'follow': 90, 'is': 10010, 'expected': 186, 'could': 1580, 'used': 610, 'measure': 27, 'printing': 10, 'related': 98, 'termed': 15, 'are': 4333, 'judged': 15, 'become': 359, 'ran': 132, 'turned': 320, 'panting': 8, 'soaked': 6, 'seems': 252, 'would': 2677, 'give': 377, 'take': 573, 'try': 125, 'probe': 5, 'make': 765, 'move': 132, 'faced': 50, 'perpetuating': 4, 'can': 1730, 'controlling': 23, 'forcing': 13, 'representing': 28, 'encourage': 45, 'establishing': 25, 'sustained': 15, 'Could': 21, 'wondered': 58, 'understood': 58, 'was': 9777, 'divides': 6, 'have': 3892, 'tends': 34, 'stirred': 15, 'announced': 88, 'sculpted': 1, 'sent': 143, 'killed': 75, "didn't": 393, 'fixed': 81, 'joining': 15, 'does': 445, 'lie': 52, 'let': 286, 'saying': 112, 'did': 994, 'takes': 86, 'mitigating': 2, 'recalling': 5, 'mistaken': 17, 'were': 3279, 'taken': 279, 'capped': 2, 'leads': 31, 'conclude': 16, 'believe': 199, 'stuck': 23, 'come': 589, 'born': 109, 'grows': 22, 'held': 259, 'trilled': 1, 'tickled': 2, 'commented': 18, 'has': 2424, 'been': 2470, 'want': 317, 'stir': 7, 'bought': 56, 'do': 1259, 'foregoing': 7, 'suggest': 53, 'looked': 366, 'decays': 1, 'charged': 57, 'guarding': 9, 'said': 1943, 'quotes': 4, 'attributes': 1, 'react': 15, 'represented': 56, 'needed': 187, 'rebelling': 3, 'planning': 72, 'implement': 3, 'prepare': 35, 'covering': 30, 'limiting': 11, 'will': 2105, 'going': 389, 'drawing': 25, 'drifted': 9, 'obtained': 115, 'provisioned': 1, 'called': 396, 'recruited': 4, 'commanded': 15, 'shown': 166, 'showed': 141, 'approximated': 5, 'forming': 21, 'occurring': 21, 'noted': 89, 'gathered': 32, 'sit': 64, 'may': 1290, 'divert': 1, 'cause': 52, "don't": 387, 'care': 75, 'witnessed': 13, 'project': 12, 'see': 727, 'wish': 86, 'budget': 2, 'saving': 18, 'indulge': 9, 'lists': 6, 'seating': 5, 'froze': 5, 'figure': 19, 'symbolize': 9, 'intimated': 5, 'hoped': 48, 'confronted': 30, 'follows': 76, 'states': 17, 'reaches': 21, 'reached': 169, 'goes': 89, 'cite': 7, 'went': 506, 'parked': 33, 'turning': 57, 'put': 424, 'retain': 11, 'required': 181, 'pass': 63, 'vote': 26, 'surviving': 13, 'serve': 103, 'given': 371, 'told': 411, 'continue': 105, 'rise': 48, 'deal': 45, 'must': 998, 'Called': 5, 'indicate': 80, 'lasting': 12, 'avoids': 3, 'dining': 26, 'sitting': 88, 'standing': 91, 'dressing': 17, "won't": 103, 'notice': 26, 'passed': 157, 'launched': 20, 'look': 268, 'comes': 133, 'experiences': 5, 'enhanced': 5, 'discovered': 73, 'being': 663, 'asked': 382, 'laughing': 27, 'added': 171, 'buying': 23, 'knew': 395, 'like': 211, 'fired': 43, 'hit': 101, 'makes': 164, 'think': 427, 'get': 719, 'riding': 41, 'laid': 77, 'plotted': 10, 'tried': 170, 'halt': 7, 'might': 658, 'magnified': 6, 'felt': 356, 'symbolized': 11, 'preferred': 26, 'refrain': 6, 'mars': 2, 'burgeoning': 4, 'swung': 48, 'produced': 90, 'offering': 22, 'accredited': 2, 'show': 199, 'adhere': 4, 'changes': 10, 'moving': 100, 'reclining': 3, 'gone': 190, "hadn't": 98, 'purify': 2, 'discover': 40, 'wore': 65, 'dangled': 2, 'compound': 2, 'equipped': 36, 'step': 20, 'circulating': 5, 'declared': 66, 'escort': 4, 'struggled': 8, 'escape': 43, 'eaten': 12, 'employed': 49, 'becomes': 104, 'menaced': 2, 'commenced': 7, 'fighting': 53, 'involved': 147, 'turns': 30, 'bring': 156, 'fulfilled': 11, 'matters': 5, 'informed': 56, 'formed': 76, 'work': 179, 'relies': 4, 'restraining': 7, 'waiting': 101, 'thought': 412, 'subdued': 7, 'effected': 12, 'absorb': 13, 'reflect': 25, 'busied': 1, 'fixing': 9, 'flies': 4, 'acting': 47, 'got': 471, 'cut': 161, 'approaching': 26, 'appeared': 135, 'live': 155, 'guard': 8, 'eliminating': 14, 'seen': 276, 'wonder': 37, "isn't": 87, 'started': 194, 'dismissed': 14, 'suppose': 69, 'studied': 79, 'taught': 49, 'performed': 34, 'count': 25, 'contains': 38, 'amounts': 20, 'landscaping': 1, 'need': 195, 'cleared': 23, 'Starting': 7, 'wanting': 16,  ...
# PRON: {'him': 2576, 'he': 6564, 'it': 6722, 'We': 679, 'we': 1973, 'It': 2037, 'She': 911, 'that': 1779, 'her': 1106, 'themselves': 270, 'they': 2773, 'You': 520, 'you': 2766, 'I': 5155, 'me': 1164, 'He': 2982, 'she': 1949, 'them': 1775, 'who': 2192, 'Who': 60, 'They': 847, 'himself': 599, 'his': 36, 'us': 670, 'itself': 304, 'Whoever': 8, 'ours': 26, 'herself': 125, 'yourselves': 8, 'myself': 128, 'whom': 142, 'Himself': 4, 'yourself': 67, 'hers': 16, "'em": 41, 'ourselves': 66, 'mine': 36, 'thee': 16, 'yours': 24, 'Her': 1, "their's": 1, 'theirs': 19, 'oneself': 5, 'em': 4, 'Thou': 6, 'Him': 43, 'Me': 16, 'ya': 4, 'Ah': 7, 'That': 19, "Y'all": 3, 'Whosoever': 1, 'whatsoever': 3, 'mee': 5, 'whoe': 2, 'What': 10, 'thou': 8, 'yow': 5, 'himselfe': 1, 'Whom': 3, 'dey': 1, 'hym': 2, 'Theirs': 2, 'u': 1, "'im": 6, 'hisself': 1, 'whoever': 5, 'ye': 10, 'Yours': 1, 'yuh': 2, 'Myself': 1, 'Thay': 1, "y'all": 1, 'whosoever': 2, 'Mine': 1, 'thum': 1, "H'all": 1, 'ownself': 1, "you'uns": 1, "we'uns": 1, 'His': 1, 'hytt': 1, 'wee': 1, 'Us': 1, 'thei': 1, 'hymselfe': 1, 'Ours': 1, "'emselves": 1, 'Thee': 1, 'um': 1}
# ADV: {'gravely': 7, 'now': 1045, 'how': 623, 'far': 374, 'especially': 156, 'etc.': 58, 'usually': 189, 'about': 511, 'back': 722, 'as': 1049, 'away': 453, 'also': 999, 'chiefly': 21, 'So': 169, 'only': 1281, 'First': 35, 'just': 731, 'too': 801, 'well': 700, 'along': 152, 'when': 1746, 'not': 4423, 'once': 361, 'indeed': 118, 'inevitably': 35, 'then': 1008, 'why': 242, 'right': 196, 'again': 534, 'always': 449, 'neatly': 19, 'sweetly': 6, 'Yet': 60, 'Nowhere': 6, 'Undoubtedly': 7, 'however': 382, 'rapidly': 65, 'first': 295, 'here': 607, 'though': 32, 'differently': 16, 'perhaps': 214, 'ever': 333, 'closely': 63, 'normally': 34, 'thereafter': 16, 'most': 673, 'more': 1188, 'Now': 269, 'good': 13, 'Thus': 165, 'even': 931, 'already': 257, 'approximately': 64, 'very': 678, 'thus': 146, 'together': 260, 'truly': 56, 'instead': 129, 'still': 703, 'where': 850, 'wonderfully': 11, 'Certainly': 26, 'Later': 38, 'otherwise': 69, 'curiously': 10, 'enough': 252, 'almost': 406, 'around': 235, 'pretty': 60, 'plastically': 1, 'little': 115, 'no': 204, 'rather': 233, 'further': 89, 'inside': 60, 'ago': 246, 'much': 435, 'immediately': 117, 'yet': 226, 'forth': 71, 'partially': 25, 'exclusively': 24, 'firmly': 49, 'weekly': 7, 'maybe': 68, 'sometimes': 162, 'often': 349, 'undoubtedly': 17, 'Actually': 38, 'nearly': 134, 'some': 19, 'quite': 230, 'commonly': 28, 'easily': 106, 'everywhere': 38, 'contemptuously': 2, 'there': 524, 'However': 170, 'remotely': 4, 'Apparently': 21, 'objectively': 3, 'dispassionately': 3, 'increasingly': 42, 'Naturally': 15, 'relatively': 84, 'When': 585, 'thoughtlessly': 1, 'deliberately': 28, 'Just': 120, 'madly': 4, 'forward': 97, 'recently': 109, 'alone': 184, 'personally': 35, 'favorably': 14, 'Where': 87, 'Then': 343, 'ill': 4, 'Outside': 12, 'rudely': 2, 'ahead': 106, 'loosely': 12, 'farther': 30, 'exceedingly': 8, 'simply': 166, 'Because': 27, 'bodily': 4, 'therefore': 156, 'presumably': 34, 'obviously': 87, 'Why': 159, 'feverishly': 2, 'noncommittally': 1, 'terribly': 18, 'Only': 97, 'carefully': 84, 'so': 1336, 'westward': 8, 'sooner': 15, 'conclusively': 7, 'better': 163, 'freely': 22, 'continually': 25, 'mechanically': 4, 'Eventually': 9, 'high': 33, 'entirely': 90, 'because': 144, 'uniformly': 6, 'Therefore': 49, 'spiritually': 7, 'wheare': 1, 'howe': 2, 'Instead': 44, 'improbably': 1, 'elsewhere': 42, 'completely': 110, 'Still': 50, 'vigorously': 13, 'later': 304, 'generally': 119, 'probably': 236, 'loose': 8, 'mercifully': 3, 'merely': 133, 'higher': 14, 'No': 116, 'Occasionally': 16, 'straightway': 1, 'anyway': 37, 'Not': 187, 'less': 200, 'e.g.': 32, 'before': 160, 'early': 94, 'How': 211, 'outside': 53, 'thoroughly': 38, 'above': 84, 'literally': 26, 'deep': 16, 'joyously': 1, 'directly': 137, 'faithfully': 5, 'exactly': 101, 'badly': 33, 'definitely': 21, 'equally': 59, 'valiantly': 1, 'slowly': 108, 'actually': 128, 'under': 14, 'desperately': 20, 'Sometime': 2, 'Finally': 60, 'quickly': 87, 'All': 65, 'long': 195, 'necessarily': 51, 'mutually': 13, 'ideally': 5, 'soon': 176, 'seriously': 46, 'supposedly': 12, 'Here': 143, 'devoutly': 1, 'straight': 58, 'never': 664, 'certainly': 117, 'frankly': 11, 'sincerely': 7, 'Besides': 25, 'gently': 31, 'wickedly': 2, 'variously': 5, 'Also': 70, 'yes': 55, 'all': 178, 'simultaneously': 32, 'accurately': 24, 'really': 267, 'subjectively': 6, 'finally': 131, 'behind': 25, 'by': 58, 'frequently': 85, 'Whenever': 13, 'previously': 55, 'physically': 18, 'suddenly': 130, 'etcetera': 9, 'permanently': 13, 'illegally': 2, 'substantially': 36, 'usual': 4, 'Sometimes': 59, 'present': 63, 'presently': 26, 'somehow': 57, 'occasionally': 32, 'else': 176, 'fairly': 57, 'thereof': 16, 'heavier': 1, 'sure': 16, 'likewise': 13, 'constantly': 41, 'shockingly': 3, 'excitedly': 7, 'greatly': 62, 'unpredictably': 2, 'rarely': 39, 'Out': 8, 'As': 55, 'but': 26, 'historically': 11, 'plenty': 7, 'preferably': 13, 'systematically': 9, 'particularly': 142, 'reportedly': 9, 'upsid ...
# .: {',': 58333, '.': 49346, '``': 8837, "''": 8789, '--': 3431, '?': 4692, '(': 2425, ')': 2456, ';': 5566, ':': 1773, '!': 1596, "'": 317, '[': 2, ']': 2}
# CONJ: {'and': 27912, 'But': 1371, 'but': 2853, 'Either': 7, 'or': 4117, "an'": 7, 'either': 182, 'plus': 51, 'And': 938, 'Yet': 76, 'nor': 159, '&': 162, 'Nor': 36, 'and/or': 17, 'Or': 88, 'yet': 57, 'Neither': 19, 'neither': 78, 'an': 11, 'butt': 2, 'An': 1, 'minus': 2, "'n'": 2, "An'": 1, 'Plus': 1, 'though': 1}
# ADP: {'of': 36078, 'as': 5656, 'to': 10985, 'if': 1465, 'for': 8833, 'by': 5044, 'at': 4963, 'before': 787, 'from': 4207, 'with': 7009, 'After': 246, 'in': 19066, 'without': 541, 'upon': 431, 'on': 5837, 'that': 6422, 'Since': 173, 'In': 1800, 'within': 313, 'Before': 68, 'among': 313, 'into': 1779, 'To': 173, "o'": 15, 'under': 632, 'At': 409, 'than': 1788, 'As': 492, 'underneath': 6, 'about': 1234, 'If': 732, 'around': 321, 'out': 436, 'Under': 56, 'above': 169, 'like': 991, 'since': 426, 'toward': 380, 'during': 453, 'according': 99, 'over': 820, 'but': 128, 'after': 812, 'For': 648, 'through': 880, 'so': 419, 'From': 163, 'including': 165, 'between': 715, 'across': 250, 'against': 616, 'behind': 217, 'With': 277, 'below': 73, 'Of': 332, 'That': 45, 'beyond': 149, 'though': 341, 'along': 190, 'off': 156, 'while': 480, 'because': 667, 'except': 163, 'until': 433, 'On': 345, 'Although': 123, 'Respecting': 1, 'unto': 16, 'per': 369, 'till': 45, 'up': 175, 'Next': 5, 'unless': 88, 'Without': 42, 'near': 149, 'By': 200, 'Besides': 16, 'excluding': 13, 'next': 37, 'regarding': 36, 'beside': 76, 'whether': 258, 'towards': 62, 'Through': 30, 'throughout': 115, 'Over': 21, 'Around': 5, 'Throughout': 18, 'down': 190, 'depending': 28, 'Between': 14, 'Until': 28, 'post': 3, ':': 20, 'outside': 78, 'concerning': 59, 'unlike': 33, 'inside': 77, 'despite': 66, 'Though': 65, 'although': 198, 'rather': 116, 'Unless': 13, 'Among': 56, 'While': 120, 'Up': 4, 'versus': 9, 'Across': 8, 'During': 132, 'Below': 7, 'onto': 60, 'past': 60, 'Beyond': 14, 'According': 29, '-': 72, 'alongside': 10, 'So': 60, 'Considering': 7, 'Despite': 38, 'beneath': 51, 'lest': 17, 'Amid': 2, 'albeit': 2, 'Like': 54, 'Along': 8, 'via': 17, 'Out': 18, 'Once': 28, 'Thru': 1, 'Near': 7, 'Upon': 20, 'whereas': 31, 'Beside': 2, 'Till': 3, 'Because': 45, 'Within': 38, 'vs.': 15, 'Except': 10, 'whereupon': 6, 'Whereas': 10, 'once': 53, 'Than': 2, 'pursuant': 20, 'Behind': 12, 'Notwithstanding': 1, 'Above': 19, 'About': 6, 'v.': 17, 'Outside': 5, 'Pending': 1, 'Per': 1, 'respecting': 1, 'plus': 16, 'Unlike': 9, 'befoh': 1, 'foh': 1, 'thru': 15, '/': 20, 'opposite': 22, 'Whether': 28, 'Into': 9, "so's": 4, 'altho': 2, 'onct': 1, "f'r": 1, 'supposing': 1, 'amongst': 4, 'round': 4, 'Toward': 6, 'att': 2, 'spite': 8, 'Opposite': 2, 'considering': 16, 'aboard': 8, 'Concerning': 3, 'But': 3, 'aftuh': 1, 'thet': 1, "f'ovuh": 1, 'behahn': 1, 'yff': 1, "durin'": 3, 'pro': 5, 'amid': 12, 'besides': 15, 'Beneath': 4, 'thatt': 1, 'behynde': 1, 'anti': 1, 'Uh': 1, 'astride': 3, 'times': 3, 'atop': 3, 'bi': 2, 'pending': 4, 'lak': 1, "'round": 1, 'minus': 4, 'following': 12, 'nearest': 3, 'amidst': 3, 'Including': 1, 'involving': 3, 'Yff': 1, 'nearer': 2, 'Rather': 3, 'inter': 1, "t'hi-im": 1, 'lahk': 1, 'synce': 1, 'uppon': 3, 'Against': 9, "'cept": 1, 'Inside': 4, 'Following': 1, 'save': 5, "tho'": 1, "s'posin'": 1, 'beefore': 1, 'towardes': 1, 'Underneath': 3, 'Regarding': 1, 'providing': 3, 'infra': 1, 'consisting': 2, 'bout': 1, "'ceptin'": 1, 'Depending': 1, "o'er": 1, 'Fur': 1, '2': 1, 'with-but-after': 1, 'Vs.': 1, 'Towards': 2, 'Down': 2, 'fer': 2, "'fore": 1, 'notwithstanding': 2, 'ere': 1, 'then': 2, 'seeing': 1, "'till": 1, 'vis-a-vis': 2, "considerin'": 1, 'Off': 1, 'Supposing': 1, 'Save': 2, 'Past': 1, 'Plus': 1, "'bout": 1, 'excepting': 1}
# DET: {'the': 62710, 'some': 1388, 'whose': 250, 'an': 3529, 'those': 782, 'which': 3539, 'My': 154, 'a': 21872, 'his': 6428, 'any': 1288, 'this': 3965, 'whatever': 86, 'each': 759, 'its': 1780, 'that': 1981, 'every': 434, 'This': 1179, 'our': 1142, 'no': 1577, 'my': 1160, 'The': 7258, 'these': 1228, 'both': 643, 'your': 868, 'These': 345, 'their': 2561, 'what': 1435, 'What': 463, 'another': 573, 'Their': 107, 'An': 197, 'A': 1198, 'her': 1779, 'Some': 206, 'That': 291, 'His': 529, 'Her': 150, 'ani': 2, 'Its': 78, 'Every': 57, 'either': 59, 'Each': 118, 'No': 242, 'Our': 110, 'Which': 21, 'Another': 111, 'Both': 87, 'neither': 22, 'Your': 55, "another's": 5, 'Any': 43, 'them': 10, 'Those': 68, 'Thy': 5, 'Neither': 15, 'whichever': 5, "'nother": 1, 'Ye': 1, 'thy': 7, 'Either': 4, 'thees': 1, 'Whatever': 25, 'mah': 2, 'hys': 5, 'anye': 1, 'Them': 2, 'Whichever': 1, "ever'": 1, 'thease': 1, 'myn': 1, 'hir': 1, "th'": 1, 'thet': 1, 'enny': 1, 'yore': 1, 'Whose': 1, 'one': 2, 'whichever-the-hell': 1, 'out': 1, 'ether': 1, 'myne': 1, "Y'r": 1, 'mine': 1, 'Whosever': 1, 'thine': 1, 'ther': 2, 'nether': 1}
# PRT: {'there': 1353, 'to': 14742, 'Such': 36, 'half': 232, 'all': 2548, 'up': 1699, 'out': 1620, "you'll": 60, "It's": 160, "kid's": 3, 'on': 556, 'off': 478, 'down': 694, "that's": 90, "it's": 142, "you'd": 28, "you're": 93, 'in': 465, 'over': 383, 'such': 274, 'There': 811, "he'd": 75, 'To': 253, "We've": 21, 'Sonuvabitch': 1, "I'm": 269, "That's": 97, "We're": 26, 'quite': 41, 'Goodbye': 2, "You're": 58, "who's": 8, 'lo': 1, "I've": 125, 'All': 210, 'Well': 116, "he's": 60, "I'll": 181, 'Oh': 109, "There's": 56, "I'd": 104, "They'll": 17, 'Uh-huh': 4, "she'd": 55, 'hell': 3, "Where'd": 4, "they'd": 24, "camera's": 1, 'Hell': 11, 'through': 61, "You'll": 30, "you've": 43, 'Dammit': 4, 'Okay': 13, 'Hey': 11, "Wally's": 2, "there's": 53, "we'll": 26, 'well': 22, "They're": 28, "leg's": 1, "it'll": 9, "they'll": 15, "We'll": 38, 'many': 20, "we'd": 22, 'Over': 9, "who'd": 8, 'Down': 2, 'Many': 5, "they're": 37, 'Bong': 6, 'Out': 13, "he'll": 16, "she's": 22, 'say': 14, 'damnit': 1, 'oh': 10, "we're": 35, 'ahem': 1, "Who's": 10, "sun's": 1, 'Jesus': 5, "what's": 15, "we've": 13, "They've": 8, 'Amen': 7, 'amen': 5, "water's": 1, 'Hello': 6, 'about': 20, "He'd": 23, "other's": 9, "What's": 38, "She's": 26, 'damn': 3, "else's": 9, "How's": 9, 'huh': 5, 'Ah': 11, "Nobody's": 2, "He's": 65, "She'd": 13, "Summer's": 1, 'alas': 6, 'Alas': 4, "You've": 24, 'rather': 5, "There'll": 1, "cane's": 1, "Kitty's": 4, "y'know": 2, "Them's": 2, 'Atta': 2, 'Uhhu': 3, 'goddamit': 1, "She'll": 6, 'good-bye': 4, "father's": 1, "Someone's": 1, 'zoooop': 1, "What'd": 1, 'OK.': 1, 'gosh': 1, 'My': 1, 'eh': 3, "It'll": 9, 'Good-by': 1, 'zounds': 2, "they've": 8, 'Please': 7, "what're": 1, 'bannnnnng': 1, "'tis": 2, 'Hmm': 1, 'diddle': 1, 'Kee-reist': 1, "sun'll": 1, "out'n": 2, "Where's": 6, 'Indeed': 2, "'tain't": 1, 'Jee-sus': 1, "name's": 4, 'hello': 4, "He'll": 14, 'Uh': 3, "that'd": 1, "Here's": 10, 'Gosh': 3, "Myra's": 1, "We'd": 10, "this'll": 1, "Mack's": 2, "Jack's": 1, 'So': 1, 'Half': 6, 'O.K.': 7, "everything's": 2, 'dear': 1, "Rob's": 1, "Guardino's": 1, "sky's": 2, 'please': 8, "thet's": 1, 'good-night': 1, 'Up': 12, 'O': 10, 'Golly': 1, "Pietro's": 1, "undersecretary's": 1, 'shucks': 1, 'Bravo': 1, 'insomma': 1, "Someone'll": 1, "They'd": 6, "Where're": 1, "'ello": 1, 'across': 12, "Knife's": 2, "Pa's": 1, "company's": 3, 'ba-a-a': 1, 'Um': 2, 'theare': 1, 'Wow': 1, 'God': 2, 'dammit': 3, 'Aah': 1, 'good-by': 1, "You'd": 8, "Baseball's": 1, 'Off': 4, "That'll": 5, "Katharine's": 1, "Arthur's": 1, 'Christ': 2, 'Mmm': 2, 'Hooray': 1, "boat's": 1, 'Heigh-ho': 1, 'dairy-oh': 1, "Somebody's": 2, 'Shh': 1, 'uh-huh': 1, 'Eh': 5, 'Howdy': 1, 'Good-bye': 2, 'bang': 2, "guy's": 2, 'Goolick': 1, 'goooolick': 1, "t'lah": 1, 'hey': 4, 'Welcome': 3, 'Hurrah': 3, 'Fiddlesticks': 1, 'Quite': 1, "there'll": 2, "kind's": 1, 'ah': 3, 'Whoa': 1, 'Haw': 1, 'Gee': 2, 'indeed': 1, 'Keerist': 1, 'after': 1, "nobody'd": 1, 'Hi': 6, "she'll": 4, "Penny's": 2, 'Aw': 2, "it'd": 3, 'Say': 1, "Springfield's": 1, 'Man': 1, "fire's": 2, 'up-pp': 1, 'Hoa-whup': 1, 'sir': 1, 'crap': 1, 'Zingggg-O': 1, 'Oh-the-pain-of-it': 1, 'golly': 1, "duds'd": 1, 'goodbye': 3, 'sake': 1, 'uh': 2, 'outta': 2, 'Da-da-da-dum': 1, 'Toot': 3, "Somebody'll": 1, 'oops': 1, "C'mon": 3, 'nary': 1, 'Kaboom': 1, 'Crunch': 1, 'Sure-sure': 1, 'Why': 3, 'godamit': 1, 'goodnight': 2, "hell's": 1, 'doggone': 1, 'Pap-pap-pap-hey': 1, "Everything's": 1, "Buckhorn's": 1, 'Yesiree': 1, 'Ahm': 1, "t'jawn": 1, "Kate's": 1, 'okay': 2, "Whyn't": 1, 'Hubba': 1, 'hubba': 1, 'Yalagaloo': 1, 'pip': 2, "Arlene's": 1, 'Aaawww': 1, 'buzz-buzz-buzz': 1, "bastard's": 1, "cowhand'd": 1, "Crosson's": 1, "Bill's": 1, "Mahzeer's": 2, 'Bah': 1, "Great's": 1, "there'd": 3, 'In': 1, "throat's": 1, 'goddammit': 1, 'my': 1, "ye're": 2, 'Harro': 1, "doctor's": 1, "t'": 1, 'Gawdamighty': 1, 'Keeeerist': 1, 'tarantara': 1, 'rum-tum-tum': 1, 'boom-boom-boom': 1, "you's": 1, 'Ugh': 1, 'Shucks': 1, "oystchers'll": 1, 'Oooo': 1, 'God ...
# ADJ: {'useful': 58, 'heavy': 107, 'such': 903, 'molten': 2, 'various': 195, 'subjective': 18, 'future': 81, 'harmless': 5, 'Gray': 9, 'North': 96, 'chief': 54, 'cold': 138, 'clear': 196, 'own': 750, 'evil': 37, 'English': 109, 'recent': 167, 'interesting': 81, 'vast': 60, 'amorphous': 6, 'substantial': 66, 'extraordinary': 30, 'dull': 27, 'upper': 66, 'Jewish': 74, 'last': 575, 'eight-and-a-half-foot': 1, 'late': 128, 'indefinite': 6, 'first': 947, 'multiple': 34, 'loose': 41, 'several': 338, 'careful': 60, 'historical': 68, 'social-economic': 3, 'European': 59, 'tariff-free': 1, 'Common': 10, 'atomic': 38, 'more': 941, 'early': 239, 'sweetest': 2, 'little': 673, 'sweet': 67, 'New': 575, 'greater': 181, '7th': 12, 'Imperial': 7, 'good': 693, 'notable': 19, 'different': 306, 'molecular': 17, 'accurate': 35, 'base': 5, 'necessary': 221, 'second': 309, 'entire': 149, 'certain': 302, 'big': 316, 'large': 347, 'stale': 4, 'pale': 56, 'veteran': 8, 'largest': 53, 'remarkable': 47, 'chainlike': 1, 'bronchial': 29, 'artery-pulmonary': 4, 'many': 896, 'Much': 31, 'relative': 43, 'quantitative': 9, 'disturbing': 14, 'Precise': 2, 'knowledgeable': 2, 'diagonalizable': 14, 'nilpotent': 12, 'crassest': 1, 'easy': 110, 'extra': 48, 'small': 517, 'new': 1060, 'delicate': 27, 'maximal': 3, 'reticulate': 3, 'maximum': 66, 'least': 325, 'other': 1627, 'black': 147, 'deep-set': 3, 'expressionless': 2, 'few': 583, 'only': 365, 'main': 98, 'common': 201, 'social': 355, 'ordinary': 66, 'great': 592, 'blank': 11, 'dirty': 35, 'same': 679, 'Perennian': 2, 'identical': 31, 'Few': 18, 'better': 233, 'even': 25, 'honest': 45, 'infamous': 3, 'alive': 57, 'open': 238, 'nervous': 24, 'pretty': 39, 'lusty': 3, 'professional': 95, 'vague': 24, 'secret': 45, 'sober': 16, 'lofty': 5, '52nd': 1, 'familial': 4, 'possible': 373, 'mutational': 1, 'resistant': 4, 'interior': 29, 'most': 382, 'National': 162, 'further': 97, 'soft': 59, 'bitter': 52, 'stagnant': 5, 'timid': 5, 'bigger': 34, 'general': 291, 'diffuse': 3, 'ideological': 21, 'latter': 112, 'luminous': 12, 'pessimistic': 6, 'closer': 18, 'effective': 128, 'third': 168, 'hard': 138, 'abrasion-resistant': 1, 'apparent': 57, 'unspoken': 3, 'legislative': 39, 'doubtful': 21, 'wild': 49, 'modern': 180, 'positive': 71, 'golden': 25, 'orange': 7, 'close': 80, 'General': 84, 'Modern': 18, 'Private': 3, 'Different': 6, 'internal': 47, 'annual': 88, 'voluntary': 22, 'needy': 5, 'South': 74, 'International': 38, 'four-jet': 1, 'routine': 15, 'normal': 132, 'Many': 100, 'public': 266, 'private': 182, 'hardworking': 1, 'potential': 39, 'negative': 50, 'helpless': 20, 'nationwide': 5, 'uppermost': 1, 'Olympic': 7, 'understandable': 13, 'Publick': 3, 'old': 568, 'sincere': 14, 'neutral': 33, 'advantageous': 5, 'German': 51, 'nuclear': 110, 'rural': 46, 'human': 259, 'unable': 54, 'dire': 1, 'smooth': 36, 'mechanical': 34, 'optical': 19, 'individual': 152, 'Trouble-free': 1, 'important': 365, 'best': 286, 'sensitive': 59, 'sub-Christian': 1, 'much': 465, 'economic': 219, 'industrial': 114, 'inexplicable': 6, 'organizational': 5, 'agricultural': 35, 'short': 192, 'dry': 51, 'edible': 5, 'sharp': 70, 'free-burning': 1, 'electric': 52, 'total': 74, 'local': 267, 'exact': 27, 'sorry': 45, 'medical': 118, 'electronic': 65, 'enormous': 37, 'simple': 155, 'collective': 31, 'accountable': 1, 'underdeveloped': 10, 'due': 114, 'sound': 50, 'fiscal': 116, 'horrible': 15, 'frequent': 32, 'gnarled': 1, 'wooden': 49, 'profound': 27, 'gradual': 15, 'ever-present': 6, 'undepicted': 4, 'orthodontic': 8, 'young': 357, 'reliable': 22, 'current': 81, 'creative': 48, 'decisive': 19, 'obscure': 11, 'Southern': 109, 'former': 128, 'Blue': 44, 'previous': 82, 'decent': 20, 'tall': 53, 'grey': 6, 'ultra-liberal': 1, 'learned': 4, 'lyric': 5, 'whole': 256, 'poor': 92, 'Southeast': 17, 'popular': 96, 'worldly': 9, 'greatest': 84, 'ultra-fast': 1, 'extreme': 51, 'free': 222, 'original': 99, 'psychological': 41, 'deep': 85, 'ostensible': 3, 'accept ...
# X: {'La': 24, 'Dolce': 5, 'Vita': 5, 'Bureau': 1, 'De': 21, 'Demographie': 1, 'Section': 1, 'Statistique': 1, 'a': 8, 'fortiori': 1, 'virtuosi': 1, 'Gracias': 2, "dell'": 1, 'Orso': 1, 'Ille': 1, 'amici': 2, 'curiae': 2, 'Kulturbund': 4, 'deja': 7, 'vue': 7, 'pas': 5, 'de': 46, 'deux': 4, 'Le': 5, 'Cygne': 1, 'Sinfonica': 1, 'Siciliana': 1, '(': 10, 'B.t.u./sq.': 1, 'ft.': 1, 'of': 2, 'material/hr./*0F./in.': 1, 'thickness': 1, ')': 10, 'engages': 5, 'voyageurs': 4, 'Gott': 1, 'strafe': 2, 'Angleterre': 1, 'Carthago': 1, 'delenda': 1, 'est': 3, 'Deus': 1, 'if': 1, 'Notitia': 1, 'se': 8, 'sub': 1, 'specie': 2, 'aeternitatis': 1, 'Gladius': 2, 'Dei': 2, 'Cavaliere': 1, 'alpha-beta-gammas': 1, 'patronne': 3, 'et': 29, 'al.': 1, 'milord': 2, 'fille': 6, 'chambre': 4, 'bevor': 1, 'die': 4, 'Nacht': 2, 'sinkt': 1, 'eine': 1, 'lange': 1, 'vielleicht': 1, 'und': 3, 'ein': 2, 'tiefes': 1, 'Vergessen': 1, 'Chateau': 1, "d'Yquem": 1, 'al': 8, 'esprit': 6, 'corps': 7, 'filles': 2, 'joie': 1, '38': 4, '-': 6, '43*0': 1, 'C.': 1, 'unagi': 1, 'zorrillas': 1, 'sic': 1, 'corroborees': 2, 'novo': 1, 'lubra': 2, 'negociant': 2, 'Sushi': 1, 'Metamorphose': 1, 'Des': 6, 'Dieux': 1, 'esse': 2, 'Weltanschauung': 1, 'prie-dieu': 1, 'Conseil': 2, 'El': 2, 'Sake': 2, 'simpliciter': 1, 'papiers': 1, 'colles': 1, 'oui': 2, 'wei': 2, 'opera': 1, 'bouffe': 1, 'maku': 2, 'persona': 1, 'non': 7, 'grata': 1, 'en': 5, 'route': 4, 'Svenskarna': 1, 'och': 2, 'deras': 1, 'Hovdingar': 1, 'kotowaza': 1, 'Tanin': 1, 'yori': 1, 'miuchi': 1, 'Paredon': 2, 'ASPIS': 1, 'SAKOS': 1, 'Rue': 4, 'Ecole': 1, 'Medecine': 1, 'Non': 2, 'lex': 1, 'sana': 1, 'Quod': 1, 'regi': 1, 'sit': 1, 'mea': 2, 'lana': 1, 'biwa': 9, 'kamikaze': 1, 'oyabun': 4, 'metier': 1, 'ngandlu': 1, "J'ai": 1, 'faim': 1, 'viva': 1, 'voce': 1, 'vade': 2, 'mecum': 2, 'Atlantes': 1, 'chili': 2, 'con': 4, 'carne': 3, 'circonscriptions': 1, 'sine': 3, 'campagna': 1, 'minber': 1, 'tultul': 4, 'culpas': 1, 'Rondo': 1, 'Sonambula': 1, 'Toujours': 1, 'gai': 1, 'vopos': 1, "dabhumaksanigalu'ahai": 1, "ksu'u'peli'afo": 1, "mai'teipa": 1, 'Francaise': 3, 'Sultane': 1, "L'Astree": 1, "L'Imperiale": 1, 'Engages': 1, 'quo': 11, 'Service': 1, 'des': 2, 'Affaires': 1, 'Indigenes': 2, 'la': 10, "Main-d'Oeuvre": 1, 'Direction': 1, 'Generale': 4, 'Gouvernement': 1, 'Nec': 1, 'minus': 1, 'salutaris': 1, 'quam': 1, 'festivus': 2, 'Se': 1, 'Habla': 1, 'Espanol': 1, 'Strukturbericht': 1, 'hoi-polloi': 1, 'Vive': 1, 'nolo': 1, 'contendere': 1, 'Von': 3, 'heute': 1, 'auf': 1, 'morgen': 1, 'Klinico': 1, 'Clericis': 1, 'Laicos': 1, 'Unam': 1, 'Sanctam': 1, 'tofu': 1, 'miso': 1, 'tempeh': 1, 'Comedie': 13, 'contadini': 2, 'le': 6, 'culte': 1, 'du': 2, 'moi': 1, "d'you": 1, 'boite': 1, 'Musique': 2, 'rata': 2, 'Angst': 2, 'Variations': 1, 'Serieuses': 1, 'Pax': 1, 'Britannica': 1, 'bel': 3, 'canto': 3, 'Prix': 2, 'intonaco': 2, 'Puttana': 1, 'cetera': 4, 'sake': 4, '29': 1, '32-degrees-C': 1, '32*0C.': 1, 'Lutte': 1, 'avec': 1, "l'Ange": 1, 'haute': 2, 'monde': 1, 'qua': 2, 'ceteras': 1, 'Grands': 3, 'Crus': 3, 'crus': 1, "L'Institut": 1, 'pour': 2, 'Recherche': 1, 'Scientifique': 1, 'En': 2, 'Afrique': 1, 'Centrale': 1, 'Mi': 1, 'diapiace': 1, 'ma': 1, 'comedie': 1, 'humaine': 1, 'troika': 1, 'Royale': 1, 'Y': 1, 'que': 1, 'sigue': 1, 'despues': 1, 'Vieux': 1, 'Carre': 1, 'adieu': 1, 'kolkhoz': 2, 'kolkhozes': 2, 'pokeneu': 1, 'phis': 1, 'coup': 2, "d'etat": 2, 'Maitres': 1, 'Allemands': 1, '17e': 1, '18e': 2, 'Siecles': 1, 'Ensemble': 1, 'Instrumental': 1, 'Internationale': 1, 'Tabellen': 1, 'Zur': 1, 'Bestimmung': 1, 'Kristallstrukturen': 1, 'Die': 4, 'Frist': 1, 'ist': 1, 'um': 1, 'wiederum': 1, 'verstrichen': 1, 'sind': 1, 'sieben': 1, 'Jahr': 1, 'circonscription': 1, 'territoire': 1, 'peccavi': 1, 'Fledermaus': 1, 'ad': 6, 'hoc': 3, 'Mais': 2, 'Bueno': 1, 'amigo': 2, 'Champs': 2, "C'est": 2, 'formidable': 1, 'merveilleux': 1, 'Vallfart': 1, 'Vandringsar': 1, 'Sie': 1, 'lacheln': 1, 'Schwarzen': 1, 'Hexen': 1, 'cordon': 1, 'sanit ...
# NUM: {'1': 526, 'One': 343, '1957': 48, 'Six': 23, '2:30.3-:36.1': 2, 'two': 1311, 'one': 2389, '26': 32, '2000': 5, 'twenty-one': 7, '3': 285, '4': 206, '1721': 2, '6': 114, '500': 16, '2100': 3, 'six': 196, 'three': 553, '1883': 6, 'fifteen': 48, 'forty': 32, 'twenty': 73, 'Twenty-four': 3, '20': 92, '1932': 3, '707': 4, 'five': 242, '25': 82, 'thirty': 56, 'sixty': 18, '17': 41, 'nine': 74, 'four': 326, "'49": 2, '1960': 172, '2': 445, 'thousand': 95, '10': 152, '12': 96, '14': 56, '55': 9, '1788': 3, '2:04': 1, '2:24': 1, '61': 4, '1946': 20, '22': 46, '13': 49, '60': 46, '1935': 10, '28': 21, '1959': 102, 'Fifteen': 8, '1950': 21, '375': 3, '161': 1, '0.36': 1, '0.16': 2, 'seventeen': 21, 'hundred': 171, '540': 2, '1600': 3, 'eighty': 10, 'one-': 5, '8': 106, '7': 91, '1914': 8, '1915': 5, 'ten': 149, 'million': 204, '1962': 35, '15': 113, '50': 61, '14-1/2': 4, '75': 20, '104': 12, '5': 142, 'Fourteen': 3, '1958': 91, '790': 1, '1900': 13, '21': 47, '30': 112, '40': 40, '5777': 1, '6,000': 5, '110': 7, 'twelve': 45, '1949': 20, 'Nineteen': 6, 'Eighty-Four': 3, '101': 2, '11:20': 4, '9': 62, 'Five': 44, 'eight': 93, '16': 54, '54,320': 1, '642': 1, '228': 1, 'Ten': 14, '1980': 4, 'Ab4,500': 1, '602.2': 1, '260': 5, '11,330': 1, 'Seven': 19, '230': 4, '18': 55, '33': 7, '08': 2, '0.906': 1, '24': 48, '2705': 1, '1920': 11, 'Three': 57, 'eighty-five': 1, '0.24': 1, '0.28': 1, '0.12': 1, '1955': 28, '1937': 10, '11': 62, '1,500': 3, 'Two': 101, '360': 4, '1543': 1, '369': 1, '23-36': 1, '1626': 1, 'one-thirty': 2, '1908': 8, '8861': 1, '950': 1, '2,418': 1, '869': 1, '2:32': 2, "'52": 3, 'seven': 94, '9-7': 1, 'eighteen': 15, 'nineteen': 12, '1907': 4, "'13": 2, '2500': 1, '1.5': 12, '480': 2, '200': 38, '2544': 1, '1886': 2, '29': 22, '70': 24, '23': 47, '113': 3, '9.8': 2, '2:22': 2, '1961': 134, '1936': 6, '1911': 3, '1906': 3, '1945': 18, '1848': 3, 'Four': 34, 'fifty': 63, 'fifty-odd': 2, '1902': 3, '1916': 5, '1919': 6, '68': 6, '32,000': 1, '2,700,877': 1, '300': 25, 'thirty-four': 6, '80,000': 2, 'zero': 17, '400': 18, '8,280': 2, '1861': 8, '1859': 10, '1577': 2, '355': 2, '149': 2, '126': 3, '187.5': 1, '189': 2, '49': 3, '1793': 5, '1479': 1, '1923': 7, '3,000': 9, 'fourteen': 28, '1948': 21, '42': 16, '1816': 1, '1593': 2, 'billion': 62, '1933': 9, '600': 8, '1607': 2, '1622': 1, '98': 3, '3.5': 4, '21-22': 1, '2:20': 2, '71': 10, '2130': 1, '1925': 9, '100': 77, 'thirty-five': 10, '1984': 1, '1953': 26, '8:30': 4, '43': 5, '150': 9, 'eighty-three': 3, '1801': 4, '80': 18, "'48": 2, '1927': 19, '3.15': 4, '10.3': 1, '30-odd': 2, '1855': 2, '7599': 1, 'Nineteen-sixty': 1, '2:36': 12, '1951': 20, '353': 5, '607': 1, '4:30': 3, '368(a)(1)': 3, '332': 3, '1959-1960': 3, '1868': 5, '160': 5, '270': 2, '1849': 2, '1819': 7, '1820': 3, '350': 8, '5-1': 3, '15-1': 1, '1845': 5, '111': 5, '603': 1, '452': 1, '2.1': 4, '1888': 6, '1891': 4, '1827': 2, '85': 10, '64': 3, '41': 11, '30-30': 1, '1928': 5, '145': 1, '1885': 3, '1910': 16, '1909': 5, '1944': 15, '2.4': 3, '65': 13, '325': 1, '1943': 12, '821,220': 1, '4.3': 3, '40,000,000': 2, '1941': 11, '1000': 11, '1931': 8, 'Thousand': 2, '5-7': 2, '13.5': 3, '1940': 15, '47.6': 1, '130': 5, 'mid-1948': 1, '1,000': 11, '46': 9, '1040': 8, 'Twenty-two': 2, '70,000': 4, '1823': 1, '06-05': 2, '192': 2, '0': 22, '95': 6, 'twenty-five': 23, 'eleven': 38, '140': 3, '5.1': 1, '1966': 4, '1720': 1, '2-4': 1, '1.1': 3, '1926': 6, '1954': 46, '3:300': 1, '700': 6, '1947': 14, '963': 1, '19': 32, '704': 1, '389': 1, '1797': 3, '0600': 1, '1956': 28, '1550': 1, '1777': 1, '2:31': 1, '36': 10, '1938': 8, '11-5': 1, '362': 2, '1223': 1, '32': 13, 'Fifty-two': 1, '1,418,000': 1, '271': 2, '307': 1, '8.6': 2, '0.075': 1, '1924': 9, '1105': 7, '1912': 15, '16,000': 3, '1844': 5, 'twenty-four': 11, '1921': 8, '1922': 8, 'forty-three': 2, '2:34': 4, '5-4': 1, '1815': 6, '99': 8, '52': 4, '5.5': 3, '8,000': 7, '10,000': 14, '2269': 1, '22111': 1, '1913': 12, '1750': 1, '1833': 1, '470': 1, '6 ...
# <div class="alert alert-block alert-success">Your emission counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Most Frequent Class Tagger
#
# Use the `pair_counts()` function and the training dataset to find the most frequent class label for each word in the training data, and populate the `mfc_table` below. The table keys should be words, and the values should be the appropriate tag string.
#
# The `MFCTagger` class is provided to mock the interface of Pomegranite HMM models so that they can be used interchangeably.

# %%
# Create a lookup table mfc_table where mfc_table[word] contains the tag label most frequently assigned to that word
from collections import namedtuple

FakeState = namedtuple("FakeState", "name")

class MFCTagger:
    # NOTE: You should not need to modify this class or any of its methods
    missing = FakeState(name="<MISSING>")
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))


# TODO: calculate the frequency of each tag being assigned to each word (hint: similar, but not
# the same as the emission probabilities) and use it to fill the mfc_table

tags_training = [tag for word, tag in data.training_set.stream()]
words_training = [word for word, tag in data.training_set.stream()]
word_counts = pair_counts(tags_training, words_training)  # pair-counting on the training data

# TODO: YOUR CODE HERE
mfc_table = {}
for word in words_training:
    tag_counts = {tag: wc[word] for tag, wc in word_counts.items() if word in wc}  # iterate all tags for word occurrences
    mfc_table[word] = max(tag_counts, key=lambda k: tag_counts[k])  # get the key with the maximum value in the dict

# check the most frequent tag for each word
print(mfc_table)

# DO NOT MODIFY BELOW THIS LINE
mfc_model = MFCTagger(mfc_table) # Create a Most Frequent Class tagger instance

assert len(mfc_table) == len(data.training_set.vocab), ""
assert all(k in data.training_set.vocab for k in mfc_table.keys()), ""
assert sum(int(k not in mfc_table) for k in data.testing_set.vocab) == 5521, ""
HTML('<div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>')
# Out:
# {'Whenever': 'ADV', 'artists': 'NOUN', ',': '.', 'indeed': 'ADV', 'turned': 'VERB', 'to': 'PRT', 'actual': 'ADJ', 'representations': 'NOUN', 'or': 'CONJ', 'molded': 'VERB', 'three-dimensional': 'ADJ', 'figures': 'NOUN', 'which': 'DET', 'were': 'VERB', 'rare': 'ADJ', 'down': 'PRT', '800': 'NUM', 'B.C.': 'NOUN', 'they': 'PRON', 'tended': 'VERB', 'reflect': 'VERB', 'reality': 'NOUN', '(': '.', 'see': 'VERB', 'Plate': 'NOUN', '6a': 'NUM', '9b': 'NUM', ')': '.', ';': '.', 'For': 'ADP', 'almost': 'ADV', 'two': 'NUM', 'months': 'NOUN', 'the': 'DET', 'defendant': 'NOUN', 'and': 'CONJ', 'world': 'NOUN', 'heard': 'VERB', 'from': 'ADP', 'individuals': 'NOUN', 'escaped': 'VERB', 'grave': 'ADJ', 'about': 'ADP', 'fathers': 'NOUN', 'mothers': 'NOUN', 'graybeards': 'NOUN', 'adolescents': 'NOUN', 'babies': 'NOUN', 'starved': 'VERB', 'beaten': 'VERB', 'death': 'NOUN', 'strangled': 'VERB', 'machine-gunned': 'VERB', 'gassed': 'VERB', 'burned': 'VERB', '.': '.', 'Clearer': 'ADJ', 'meaning': 'NOUN', 'Yes': 'ADV', 'gentlemen': 'NOUN', 'I': 'PRON', 'am': 'VERB', 'getting': 'VERB', 'point': 'NOUN', 'my': 'DET', 'About': 'ADV', 'same': 'ADJ', 'time': 'NOUN', 'Alleghenies': 'NOUN', 'Poconos': 'NOUN', 'in': 'ADP', 'Pennsylvania': 'NOUN', 'are': 'VERB', 'magnificent': 'ADJ', '--': '.', 'Renovo': 'NOUN', 'holds': 'VERB', 'its': 'DET', 'annual': 'ADJ', 'Flaming': 'VERB', 'Foliage': 'NOUN', 'Festival': 'NOUN', 'on': 'ADP', 'Oct.': 'NOUN', '14': 'NUM', '15': 'NUM', "There's": 'PRT', 'no': 'DET', 'doubt': 'NOUN', 'this': 'DET', 'Tim': 'NOUN', 'sneaked': 'VERB', 'back': 'ADV', 'killed': 'VERB', 'Mrs.': 'NOUN', 'Buck': 'NOUN', 'The': 'DET', "cowboy's": 'NOUN', 'humorous': 'ADJ', 'name': 'NOUN', 'for': 'ADP', 'a': 'DET', 'cow': 'NOUN', "givin'": 'VERB', 'milk': 'NOUN', 'was': 'VERB', '``': '.', 'pitcher': 'NOUN', "''": '.', 'It': 'PRON', 'is': 'VERB', 'therefore': 'ADV', 'not': 'ADV', 'surprising': 'VERB', 'that': 'ADP', 'resist': 'VERB', 'lure': 'NOUN', 'of': 'ADP', 'marriage': 'NOUN', 'trap': 'NOUN', 'domesticity': 'NOUN', 'like': 'ADP', 'cats': 'NOUN', 'determined': 'VERB', 'tame': 'ADJ', 'their': 'DET', 'sexual': 'ADJ', 'energy': 'NOUN', 'A': 'DET', 'shielded': 'VERB', 'thermocouple': 'NOUN', 'used': 'VERB', 'measure': 'NOUN', 'upstream': 'ADV', 'temperature': 'NOUN', 'transpiring': 'VERB', 'gas': 'NOUN', 'ideals': 'NOUN', 'country': 'NOUN', 'deeply': 'ADV', 'indebted': 'ADJ', 'Protestantism': 'NOUN', 'older': 'ADJ', 'stock': 'NOUN', 'Matsuo': 'NOUN', 'laughed': 'VERB', 'slung': 'VERB', 'rifle': 'NOUN', 'Rousseau': 'NOUN', 'asked': 'VERB', 'Dave': 'NOUN', 'Trager': 'NOUN', 'who': 'PRON', 'quite': 'ADV', 'showman': 'NOUN', 'boss': 'NOUN', "Chicago's": 'NOUN', 'new': 'ADJ', 'pro': 'ADP', 'basketball': 'NOUN', 'Packers': 'NOUN', 'debuting': 'VERB', 'International': 'ADJ', 'club': 'NOUN', 'exclusive': 'ADJ', 'use': 'NOUN', 'season': 'NOUN', 'ticket': 'NOUN', 'holders': 'NOUN', 'Stock': 'NOUN', 'Yards': 'NOUN', 'Inn': 'NOUN', 'While': 'ADP', 'he': 'PRON', 'waited': 'VERB', 'living': 'VERB', 'room': 'NOUN', 'Frank': 'NOUN', 'Graham': 'NOUN', 'Journal-American': 'NOUN', 'sports': 'NOUN', 'columnist': 'NOUN', 'Health': 'NOUN', 'excellent': 'ADJ', 'Serenity': 'NOUN', 'if': 'ADP', 'one': 'NUM', 'fortunate': 'ADJ', 'enough': 'ADV', 'achieve': 'VERB', 'it': 'PRON', 'so': 'ADV', 'good': 'ADJ', 'as': 'ADP', 'joy': 'NOUN', 'but': 'CONJ', 'something': 'NOUN', 'should': 'VERB', 'have': 'VERB', 'dramatic': 'ADJ', 'form': 'NOUN', 'with': 'ADP', 'pleasing': 'ADJ', 'language': 'NOUN', 'portray': 'VERB', 'incidents': 'NOUN', 'arouse': 'VERB', 'pity': 'NOUN', 'fear': 'NOUN', 'purges': 'NOUN', 'these': 'DET', 'emotions': 'NOUN', 'audience': 'NOUN', 'She': 'PRON', 'worked': 'VERB', 'domestic': 'ADJ', 'first': 'ADJ', 'Newport': 'NOUN', 'year': 'NOUN', 'then': 'ADV', 'South': 'NOUN', 'Bethlehem': 'NOUN', 'another': 'DET', 'These': 'DET', 'tests': 'NOUN', 'accelerated': 'VERB', 'must': 'VERB', 'be': 'VERB', 'repeated': 'VERB', 'evaluate': 'VERB', 'dimensional': 'ADJ', 'changes': 'NOUN', ...
# <div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>

# %% [markdown]
# ### Making Predictions with a Model
# The helper functions provided below interface with Pomegranate network models & the mocked MFCTagger to take advantage of the [missing value](http://pomegranate.readthedocs.io/en/latest/nan.html) functionality in Pomegranate through a simple sequence decoding function. Run these functions, then run the next cell to see some of the predictions made by the MFC tagger.

# %%
def replace_unknown(sequence):
    """Return a copy of the input sequence where each unknown word is replaced
    by the literal string value 'nan'. Pomegranate will ignore these values
    during computation.
    """
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):
    """X should be a 1-D sequence of observations for the model to predict"""
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]  # do not show the start/end state predictions

# %% [markdown]
# ### Example Decoding Sequences with MFC Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence Content:\n-----------------")
    print(data.sentences[key].words)
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Sentence Content:
# -----------------
# ('and', 'August', '15', ',', 'November', '15', ',', 'February', '17', ',', 'and', 'May', '15', ',', '(', 'Cranston', ')', '.')
# Predicted labels:
# -----------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
#
# Actual labels:
# --------------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')
#
#
# Sentence Key: b100-23146
#
# Sentence Content:
# -----------------
# ('She', 'had', 'the', 'opportunity', 'that', 'few', 'clever', 'women', 'can', 'resist', ',', 'of', 'showing', 'her', 'superiority', 'in', 'argument', 'over', 'a', 'man', '.')
# Predicted labels:
# -----------------
# ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
#
# Sentence Key: b100-35462
#
# Sentence Content:
# -----------------
# ('The', 'same', 'conclusions', 'can', 'be', 'drawn', 'from', 'the', 'other', 'physical', 'evidence', 'of', 'the', 'Dark', 'ages', ',', 'from', 'linguistic', 'distribution', ',', 'and', 'from', 'the', 'survivals', 'of', 'early', 'social', ',', 'political', ',', 'and', 'religious', 'patterns', 'into', 'later', 'ages', '.')
# Predicted labels:
# -----------------
# ['DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', '<MISSING>', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADV', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')

# %% [markdown]
# ### Evaluating Model Accuracy
#
# The function below will evaluate the accuracy of the MFC tagger on the collection of all sentences from a text corpus.

# %%
def accuracy(X, Y, model):
    """Calculate the prediction accuracy by using the model to decode each sequence
    in the input X and comparing the prediction with the true labels in Y.
    
    The X should be an array whose first dimension is the number of sentences to test,
    and each element of the array should be an iterable of the words in the sequence.
    The arrays X and Y should have the exact same shape.
    
    X = [("See", "Spot", "run"), ("Run", "Spot", "run", "fast"), ...]
    Y = [(), (), ...]
    """
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %% [markdown]
# #### Evaluate the accuracy of the MFC tagger
# Run the next cell to evaluate the accuracy of the tagger on the training and test corpus.

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))

assert mfc_training_acc >= 0.955, "Uh oh. Your MFC accuracy on the training set doesn't look right."
assert mfc_testing_acc >= 0.925, "Uh oh. Your MFC accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>')
# Out:
# training accuracy mfc_model: 95.72%
# testing accuracy mfc_model: 93.02%
# <div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>

# %% [markdown]
# ## Step 3: Build an HMM tagger
# ---
# The HMM tagger has one hidden state for each possible tag, and parameterized by two distributions: the emission probabilties giving the conditional probability of observing a given **word** from each hidden state, and the transition probabilities giving the conditional probability of moving between **tags** during the sequence.
#
# We will also estimate the starting probability distribution (the probability of each **tag** being the first tag in a sequence), and the terminal probability distribution (the probability of each **tag** being the last tag in a sequence).
#
# The maximum likelihood estimate of these distributions can be calculated from the frequency counts as described in the following sections where you'll implement functions to count the frequencies, and finally build the model. The HMM model will make predictions according to the formula:
#
# $$t_i^n = \underset{t_i^n}{\mathrm{argmax}} \prod_{i=1}^n P(w_i|t_i) P(t_i|t_{i-1})$$
#
# Refer to Speech & Language Processing [Chapter 10](https://web.stanford.edu/~jurafsky/slp3/10.pdf) for more information.

# %% [markdown]
# ### IMPLEMENTATION: Unigram Counts
#
# Complete the function below to estimate the occurrence frequency of each symbol over all of the input sequences. The unigram probabilities in our HMM model are estimated from the formula below, where N is the total number of samples in the input. (You only need to compute the counts for now.)
#
# $$P(tag_1) = \frac{C(tag_1)}{N}$$

# %%
def unigram_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequence list that
    counts the number of occurrences of the value in the sequences list. The sequences
    collection should be a 2-dimensional array.
    
    For example, if the tag NOUN appears 275558 times over all the input sequences,
    then you should return a dictionary such that your_unigram_counts[NOUN] == 275558.
    """
    # TODO: Finish this function!
    u_counts = {}
    for _, tag in sequences:
        if tag not in u_counts:
            u_counts[tag] = 0
        u_counts[tag] += 1
    return u_counts

# TODO: call unigram_counts with a list of tag sequences from the training set
tag_unigrams = unigram_counts(data.training_set.stream())

assert set(tag_unigrams.keys()) == data.training_set.tagset, \
       "Uh oh. It looks like your tag counts doesn't include all the tags!"
assert min(tag_unigrams, key=tag_unigrams.get) == 'X', \
       "Hmmm...'X' is expected to be the least common class"
assert max(tag_unigrams, key=tag_unigrams.get) == 'NOUN', \
       "Hmmm...'NOUN' is expected to be the most common class"
HTML('<div class="alert alert-block alert-success">Your tag unigrams look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your tag unigrams look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Bigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each pair of symbols in each of the input sequences. These counts are used in the HMM model to estimate the bigram probability of two tags from the frequency counts according to the formula: $$P(tag_2|tag_1) = \frac{C(tag_2|tag_1)}{C(tag_2)}$$

# %%
def bigram_counts(sequences):
    """Return a dictionary keyed to each unique PAIR of values in the input sequences
    list that counts the number of occurrences of pair in the sequences list. The input
    should be a 2-dimensional array.
    
    For example, if the pair of tags (NOUN, VERB) appear 61582 times, then you should
    return a dictionary such that your_bigram_counts[(NOUN, VERB)] == 61582
    """

    # TODO: Finish this function!
    bi_counts = {}
    for tag, tag_next in sequences:
        if (tag, tag_next) not in bi_counts:
            bi_counts[(tag, tag_next)] = 0
        bi_counts[(tag, tag_next)] += 1
    return bi_counts
    

# TODO: call bigram_counts with a list of tag sequences from the training set
tags = [tag for word, tag in data.training_set.stream()]  # collect all tags
assert(len(tags) > 0), "Tag list should have non-zero length."
tags_pair = [(tag, tag_next) for tag, tag_next in zip(tags[:-1], tags[1:])]  # collect all continuous tag pairs

tag_bigrams = bigram_counts(tags_pair)

assert len(tag_bigrams) == 144, \
       "Uh oh. There should be 144 pairs of bigrams (12 tags x 12 tags)"
assert min(tag_bigrams, key=tag_bigrams.get) in [('X', 'NUM'), ('PRON', 'X')], \
       "Hmmm...The least common bigram should be one of ('X', 'NUM') or ('PRON', 'X')."
assert max(tag_bigrams, key=tag_bigrams.get) in [('DET', 'NOUN')], \
       "Hmmm...('DET', 'NOUN') is expected to be the most common bigram."
HTML('<div class="alert alert-block alert-success">Your tag bigrams look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your tag bigrams look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Sequence Starting Counts
# Complete the code below to estimate the bigram probabilities of a sequence starting with each tag.

# %%
def starting_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the beginning of
    a sequence.
    
    For example, if 8093 sequences start with NOUN, then you should return a
    dictionary such that your_starting_counts[NOUN] == 8093
    """
    # TODO: Finish this function!
    st_counts = {}
    for tag in sequences:
        if tag not in st_counts:
            st_counts[tag] = 0
        st_counts[tag] += 1
    return st_counts

# TODO: Calculate the count of each tag starting a sequence
starting_tags = [tag[0] for tag in data.training_set.Y]
tag_starts = starting_counts(starting_tags)

assert len(tag_starts) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_starts, key=tag_starts.get) == 'X', "Hmmm...'X' is expected to be the least common starting bigram."
assert max(tag_starts, key=tag_starts.get) == 'DET', "Hmmm...'DET' is expected to be the most common starting bigram."
HTML('<div class="alert alert-block alert-success">Your starting tag counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your starting tag counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Sequence Ending Counts
# Complete the function below to estimate the bigram probabilities of a sequence ending with each tag.

# %%
def ending_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the end of
    a sequence.
    
    For example, if 18 sequences end with DET, then you should return a
    dictionary such that your_starting_counts[DET] == 18
    """
    # TODO: Finish this function!
    end_counts = {}
    for tag in sequences:
        if tag not in end_counts:
            end_counts[tag] = 0
        end_counts[tag] += 1
    return end_counts

# TODO: Calculate the count of each tag ending a sequence
ending_tags = [tag[-1] for tag in data.training_set.Y]
tag_ends = ending_counts(ending_tags)

assert len(tag_ends) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_ends, key=tag_ends.get) in ['X', 'CONJ'], "Hmmm...'X' or 'CONJ' should be the least common ending bigram."
assert max(tag_ends, key=tag_ends.get) == '.', "Hmmm...'.' is expected to be the most common ending bigram."
HTML('<div class="alert alert-block alert-success">Your ending tag counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your ending tag counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Basic HMM Tagger
# Use the tag unigrams and bigrams calculated above to construct a hidden Markov tagger.
#
# - Add one state per tag
#     - The emission distribution at each state should be estimated with the formula: $P(w|t) = \frac{C(t, w)}{C(t)}$
# - Add an edge from the starting state `basic_model.start` to each tag
#     - The transition probability should be estimated with the formula: $P(t|start) = \frac{C(start, t)}{C(start)}$
# - Add an edge from each tag to the end state `basic_model.end`
#     - The transition probability should be estimated with the formula: $P(end|t) = \frac{C(t, end)}{C(t)}$
# - Add an edge between _every_ pair of tags
#     - The transition probability should be estimated with the formula: $P(t_2|t_1) = \frac{C(t_1, t_2)}{C(t_1)}$

# %%
basic_model = HiddenMarkovModel(name="base-hmm-tagger")

# TODO: create states with emission probability distributions P(word | tag) and add to the model
# (Hint: you may need to loop & create/add new states)
# add new states
states = []
for tag in data.training_set.tagset:
    wc = word_counts[tag]
    n_occ = sum(wc.values())  # total number of occurrences for the current tag
    dist = DiscreteDistribution({word: count/n_occ for word, count in wc.items()})
    states.append(State(dist, name=tag))
basic_model.add_states(*states)

# TODO: add edges between states for the observed transition frequencies P(tag_i | tag_i-1)
# (Hint: you may need to loop & add transitions

# edges from the starting state
for state in states:
    p_start = tag_starts[state.name] / sum(tag_starts.values())
    basic_model.add_transition(basic_model.start, state, p_start)

# edges between every pair of tags
for state_in in states:
    tag_in = state_in.name
    tag_out_list = [tag_next for tag, tag_next in tag_bigrams if tag == tag_in]  # find all possible tags as end of edges
    n_occ = sum([tag_bigrams[(tag_in, tag_out)] for tag_out in tag_out_list])  # sum of number of occurrences of the current tag
    for tag_out in tag_out_list:
        state_out = states[[state.name for state in states].index(tag_out)]  # locate the state with name tag_out
        p_in_out = tag_bigrams[(tag_in, tag_out)] / n_occ
        basic_model.add_transition(state_in, state_out, p_in_out)

# edges to the end state
for state in states:
    p_end = tag_ends[state.name] / sum(tag_ends.values())
    basic_model.add_transition(state, basic_model.end, p_end)

# plot the HMM model
basic_model.plot()

# NOTE: YOU SHOULD NOT NEED TO MODIFY ANYTHING BELOW THIS LINE
# finalize the model
basic_model.bake()

assert all(tag in set(s.name for s in basic_model.states) for tag in data.training_set.tagset), \
       "Every state in your network should use the name of the associated tag, which must be one of the training set tags."
assert basic_model.edge_count() == 168, \
       ("Your network should have an edge from the start node to each state, one edge between every " +
        "pair of tags (states), and an edge from each state to the end node.")
HTML('<div class="alert alert-block alert-success">Your HMM network topology looks good!</div>')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: UserWarning: Install pygraphviz for nicer visualizations
# <div class="alert alert-block alert-success">Your HMM network topology looks good!</div>

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, basic_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, basic_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))

assert hmm_training_acc > 0.97, "Uh oh. Your HMM accuracy on the training set doesn't look right."
assert hmm_testing_acc > 0.955, "Uh oh. Your HMM accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your HMM tagger accuracy looks correct! Congratulations, you\'ve finished the project.</div>')
# Out:
# training accuracy basic hmm model: 97.53%
# testing accuracy basic hmm model: 95.96%
# <div class="alert alert-block alert-success">Your HMM tagger accuracy looks correct! Congratulations, you've finished the project.</div>

# %% [markdown]
# ### Example Decoding Sequences with the HMM Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence Content:\n-----------------")
    print(data.sentences[key].words)
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, basic_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-28144
#
# Sentence Content:
# -----------------
# ('and', 'August', '15', ',', 'November', '15', ',', 'February', '17', ',', 'and', 'May', '15', ',', '(', 'Cranston', ')', '.')
# Predicted labels:
# -----------------
# ['CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.']
#
# Actual labels:
# --------------
# ('CONJ', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'NOUN', 'NUM', '.', 'CONJ', 'NOUN', 'NUM', '.', '.', 'NOUN', '.', '.')
#
#
# Sentence Key: b100-23146
#
# Sentence Content:
# -----------------
# ('She', 'had', 'the', 'opportunity', 'that', 'few', 'clever', 'women', 'can', 'resist', ',', 'of', 'showing', 'her', 'superiority', 'in', 'argument', 'over', 'a', 'man', '.')
# Predicted labels:
# -----------------
# ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
#
# Sentence Key: b100-35462
#
# Sentence Content:
# -----------------
# ('The', 'same', 'conclusions', 'can', 'be', 'drawn', 'from', 'the', 'other', 'physical', 'evidence', 'of', 'the', 'Dark', 'ages', ',', 'from', 'linguistic', 'distribution', ',', 'and', 'from', 'the', 'survivals', 'of', 'early', 'social', ',', 'political', ',', 'and', 'religious', 'patterns', 'into', 'later', 'ages', '.')
# Predicted labels:
# -----------------
# ['DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
#
# Actual labels:
# --------------
# ('DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADJ', '.', 'ADJ', '.', 'CONJ', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.')

# %% [markdown]
# ## Finishing the project
# ---
#
# <div class="alert alert-block alert-info">
# **Note:** **SAVE YOUR NOTEBOOK**, then run the next cell to generate an HTML copy. You will zip & submit both this file and the HTML copy for review.
# </div>

# %%
# !!jupyter nbconvert *.ipynb
# Out:
# ['[NbConvertApp] Converting notebook HMM Tagger.ipynb to html',
#  '[NbConvertApp] Writing 346860 bytes to HMM Tagger.html',
#  '[NbConvertApp] Converting notebook HMM warmup (optional).ipynb to html',
#  '[NbConvertApp] Writing 309843 bytes to HMM warmup (optional).html']

# %% [markdown]
# ## Step 4: [Optional] Improving model performance
# ---
# There are additional enhancements that can be incorporated into your tagger that improve performance on larger tagsets where the data sparsity problem is more significant. The data sparsity problem arises because the same amount of data split over more tags means there will be fewer samples in each tag, and there will be more missing data  tags that have zero occurrences in the data. The techniques in this section are optional.
#
# - [Laplace Smoothing](https://en.wikipedia.org/wiki/Additive_smoothing) (pseudocounts)
#     Laplace smoothing is a technique where you add a small, non-zero value to all observed counts to offset for unobserved values.
#
# - Backoff Smoothing
#     Another smoothing technique is to interpolate between n-grams for missing data. This method is more effective than Laplace smoothing at combatting the data sparsity problem. Refer to chapters 4, 9, and 10 of the [Speech & Language Processing](https://web.stanford.edu/~jurafsky/slp3/) book for more information.
#
# - Extending to Trigrams
#     HMM taggers have achieved better than 96% accuracy on this dataset with the full Penn treebank tagset using an architecture described in [this](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf) paper. Altering your HMM to achieve the same performance would require implementing deleted interpolation (described in the paper), incorporating trigram probabilities in your frequency tables, and re-implementing the Viterbi algorithm to consider three consecutive states instead of two.
#
# ### Obtain the Brown Corpus with a Larger Tagset
# Run the code below to download a copy of the brown corpus with the full NLTK tagset. You will need to research the available tagset information in the NLTK docs and determine the best way to extract the subset of NLTK tags you want to explore. If you write the following the format specified in Step 1, then you can reload the data using all of the code above for comparison.
#
# Refer to [Chapter 5](http://www.nltk.org/book/ch05.html) of the NLTK book for more information on the available tagsets.

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import brown

nltk.download('brown')
training_corpus = nltk.corpus.brown
training_corpus.tagged_sents()[0]
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\lzhu14\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]
